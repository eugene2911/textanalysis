# %%
import nltk
nltk.download()

# %% [markdown]
# # Twitter Text Analysis

# %% [markdown]
# In this file we have the raw data from DeerAntMan, and we have another jupiter notebook that allows us to take that data, unzip it, and create a csv file that holds every tweet regarding the Ant man movie, as well as who wrote it, the time it was posted and the date.
#
# What we want to do is take the body of each text and count favorable words, unfavorable words, and add them together. We want to do this globally and with each tweet individually. We should also count the number of tweets that are favorable and unfavorable. Lastly we should try to sort the tweets out by how good they are on a scale.

# %% [markdown]
# First lets import panda so we can read the CSV file. So far no problem until 21325

# %% [markdown]
# Actually consider trying to write this program in the other file, meaning, write this as a continuation of loading a tidy twitter dataFrame, because there you allready have all the smalldata, you don't have to try to open the csv and maybe we can completely circumvent the problem of having touble with reading and doing the text analysis from the antman_all.csv file********

# %%
#This is a new line, needs testing, delete to go back to where you were# with open('antman_all.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)

# %%
import os
import pandas as pd
import csv
df1=pd.read_csv('antman_all.csv', nrows=21345, error_bad_lines=False)
df1
# Out:
#       Unnamed: 0         displayName  \
# 0              0  Det2whereeverMusic
# 1              1         Darrel Long
# 2              2        Fleek Mill.♥
# 3              3      Ant & Dec News
# 4              4  Pockets on Finesse
# 5              5           Ray Beale
# 6              6  Pockets on Finesse
# 7              7      Ant & Dec News
# 8              8            John Dey
# 9              9  Pockets on Finesse
# 10            10  Pockets on Finesse
# 11            11  Pockets on Finesse
# 12            12  Pockets on Finesse
# 13            13  Pockets on Finesse
# 14            14  Pockets on Finesse
# 15            15  Pockets on Finesse
# 16            16  Pockets on Finesse
# 17            17  Pockets on Finesse
# 18            18  Pockets on Finesse
# 19            19  Pockets on Finesse
# 20            20  Pockets on Finesse
# 21            21  Pockets on Finesse
# 22            22  Pockets on Finesse
# 23            23  Pockets on Finesse
# ...
